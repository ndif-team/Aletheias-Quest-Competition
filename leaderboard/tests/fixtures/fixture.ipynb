# %%
import pandas as pd
# Deterministic, offline submission used to test the runner without NDIF/HF.
ids = [0, 1, 2, 3, 4]
preds = [0.9, 0.8, 0.2, 0.1, 0.6]
pd.DataFrame({"id": ids, "prediction": preds}).to_csv("submission.csv", index=False)
print("wrote", len(ids), "predictions")
